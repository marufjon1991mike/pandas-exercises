# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series

# %%
models = ['Honda', 'Malibu', 'Mazda', 'Jaguar', 'Toyota', 'Lacetti', 'BMW']

# %%
cars_dict = {
    "Malibu" : 40000,
    "Lacetti" : 20000,
    "Toyota" : 45000,
    "Mazda" : 52000,
    "Honda" : 38000
}

# %%
cars1 = Series(cars_dict)

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
cars2 = Series(cars_dict, index = models)

# %%
cars2
# Out:
# Honda      38000.0
# Malibu     40000.0
# Mazda      52000.0
# Jaguar         NaN
# Toyota     45000.0
# Lacetti    20000.0
# BMW            NaN
# dtype: float64

# %%
cars2.isnull() #qiymati bo'lmasa True qaytaradi
# Out:
# Honda      False
# Malibu     False
# Mazda      False
# Jaguar      True
# Toyota     False
# Lacetti    False
# BMW         True
# dtype: bool

# %%
cars2.notnull()
# Out:
# Honda       True
# Malibu      True
# Mazda       True
# Jaguar     False
# Toyota      True
# Lacetti     True
# BMW        False
# dtype: bool

# %%
cars1 + cars2 #indeksi bo'yicha qiymatlarni qo'shadi.
# Out:
# BMW             NaN
# Honda       76000.0
# Jaguar          NaN
# Lacetti     40000.0
# Malibu      80000.0
# Mazda      104000.0
# Toyota      90000.0
# dtype: float64

# %%
cars2.name = 'Avtosalon' #cars2 ni nomlash

# %%
cars2.index.name = 'Modellar' #cars2 indekslarini nomlash

# %%
cars2
# Out:
# Modellar
# Honda      38000.0
# Malibu     40000.0
# Mazda      52000.0
# Jaguar         NaN
# Toyota     45000.0
# Lacetti    20000.0
# BMW            NaN
# Name: Avtosalon, dtype: float64
