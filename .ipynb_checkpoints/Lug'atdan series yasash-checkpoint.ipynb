# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series

# %%
cars_dict = {
    "Malibu" : 40000,
    "Lacetti" : 20000,
    "Toyota" : 45000,
    "Mazda" : 52000,
    "Honda" : 38000
}

# %%
type(cars_dict)
# Out:
# dict

# %%
cars = Series(cars_dict) # car_dict lug'atni Seriesga o'tkazadi

# %%
cars
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
"Malibu" in cars
# Out:
# True

# %%
"BMW" in cars
# Out:
# False

# %%
cars["Toyota"]
# Out:
# np.int64(45000)

# %%
cars_dict
# Out:
# {'Malibu': 40000,
#  'Lacetti': 20000,
#  'Toyota': 45000,
#  'Mazda': 52000,
#  'Honda': 38000}

# %%
models = ['Honda', 'Malibu', 'Mazda', 'Jaguar', 'Toyota', 'Lacetti', 'BMW']

# %%
cars2 = Series(car_dict, index = models) # cars2 ni indekslarini models(list) ketmaketligida indekslaydi

# %%
cars2 #modelsda mavjud bo'lmagan qiymatga NaN qaytaradi
# Out:
# Honda      38000.0
# Malibu     40000.0
# Mazda      52000.0
# Jaguar         NaN
# Toyota     45000.0
# Lacetti    20000.0
# BMW            NaN
# dtype: float64
