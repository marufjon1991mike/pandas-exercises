# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series

# %%
obj = Series([2, 5, 12, -4.5])

# %%
print(obj)
# Out:
# 0     2.0
# 1     5.0
# 2    12.0
# 3    -4.5
# dtype: float64

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
obj.values # obj qiymatlarini qaytaradi
# Out:
# array([ 2. ,  5. , 12. , -4.5])

# %%
obj.index # obj indeksi 0 dan boshlanadi 4 gacha 1 qadam bilan
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[0]
# Out:
# np.float64(2.0)

# %%
obj2 = Series([3, 2.5, -7, 1], index = ["a","b","c","d"])

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2
# Out:
# a    3.0
# b    2.5
# c   -7.0
# d    1.0
# dtype: float64

# %%
obj2[["d","b","a"]]
# Out:
# d    1.0
# b    2.5
# a    3.0
# dtype: float64

# %%
obj2 * 2
# Out:
# a     6.0
# b     5.0
# c   -14.0
# d     2.0
# dtype: float64

# %%
obj2[obj2 < 3] # obj2 ichidagi 3 dan kichik qiymatlarni qaytaradi
# Out:
# b    2.5
# c   -7.0
# d    1.0
# dtype: float64

# %%
obj2 + 3
# Out:
# a    6.0
# b    5.5
# c   -4.0
# d    4.0
# dtype: float64
