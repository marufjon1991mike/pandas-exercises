# %%
import pandas as pd

# %%
import numpy as np

# %%
data = {
    'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53],
    'Zichlik':[79.77, 78.68, 77.53, 76.34, 75.13, 73.91, 72.71, 67.03]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.48    78.68
# 2  2019        32.9  1.56    77.53
# 3  2018        32.5  1.62    76.34
# 4  2017        31.9  1.65    75.13
# 5  2016        31.4  1.66    73.91
# 6  2015        30.9  1.64    72.71
# 7  2010        28.5  1.53    67.03

# %%
df.index = [21, 20, 19, 18,17, 16, 15, 10] #indekslarning qiymatini o'zgartirish

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.48    78.68
# 19  2019        32.9  1.56    77.53
# 18  2018        32.5  1.62    76.34
# 17  2017        31.9  1.65    75.13
# 16  2016        31.4  1.66    73.91
# 15  2015        30.9  1.64    72.71
# 10  2010        28.5  1.53    67.03

# %%
ind = [21, 20, 19, 18, 17, 16, 15, 10]
ind.sort()

# %%
ind
# Out:
# [10, 15, 16, 17, 18, 19, 20, 21]

# %%
df.reindex(ind) #qayta indekslash, yangi datafreym qaytaradi asl datafreym o'zgarmaydi
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df # datafreym o'zgargani yoq
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.48    78.68
# 19  2019        32.9  1.56    77.53
# 18  2018        32.5  1.62    76.34
# 17  2017        31.9  1.65    75.13
# 16  2016        31.4  1.66    73.91
# 15  2015        30.9  1.64    72.71
# 10  2010        28.5  1.53    67.03

# %%
df = df.reindex(ind) # asl datafreymni o'zgartirish

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.reindex([10,15,20]) #faqatgina berilgan indeksdagi qiymatlarni saqlab qoladi
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 20  2020        33.5  1.48    78.68

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.reindex(index = range(10,22)) #yangi indeks va qiymatlar qo'shadi kiritilmagan qiymatlarga NaN qaytaradi
# Out:
#        Yil  Aholi soni  Temp  Zichlik
# 10  2010.0        28.5  1.53    67.03
# 11     NaN         NaN   NaN      NaN
# 12     NaN         NaN   NaN      NaN
# 13     NaN         NaN   NaN      NaN
# 14     NaN         NaN   NaN      NaN
# 15  2015.0        30.9  1.64    72.71
# 16  2016.0        31.4  1.66    73.91
# 17  2017.0        31.9  1.65    75.13
# 18  2018.0        32.5  1.62    76.34
# 19  2019.0        32.9  1.56    77.53
# 20  2020.0        33.5  1.48    78.68
# 21  2021.0        33.9  1.54    79.77

# %%
df.reindex(index = range(10,22), method = 'nearest') #NaN qiymatlarni eng yaqin qiymatlar bilan almashtirdai
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 11  2010        28.5  1.53    67.03
# 12  2010        28.5  1.53    67.03
# 13  2015        30.9  1.64    72.71
# 14  2015        30.9  1.64    72.71
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.reindex(index = range(10,22), method = 'ffill') # bir xil qiymat qo'shadi
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 11  2010        28.5  1.53    67.03
# 12  2010        28.5  1.53    67.03
# 13  2010        28.5  1.53    67.03
# 14  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df2 = df.reindex(columns = ['Aholi soni', 'Temp', 'Zichlik']) #Yil degan ustunni olib tashlash

# %%
df2.sample() # tasodifiy qiymat qaytaradi
# Out:
#     Aholi soni  Temp  Zichlik
# 21        33.9  1.54    79.77

# %%
df2.sample(3) # 3 ta tasodifiy qiymat qaytaradi
# Out:
#     Aholi soni  Temp  Zichlik
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 16        31.4  1.66    73.91

# %%
df.loc[[15,17,18,20],['Aholi soni', 'Temp', 'Zichlik']] #faqat belgilangan indeksdagi qiymalarni qaytaradi
# Out:
#     Aholi soni  Temp  Zichlik
# 15        30.9  1.64    72.71
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 20        33.5  1.48    78.68

# %%
df2 = df.drop([10]) # 10 indexni tashlab yuborish
df2
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.drop([10,15])
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.drop('Yil', axis = 1) #ustunlarni tashlab yuborish
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 16        31.4  1.66    73.91
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77

# %%
df.drop('Yil', axis = 'columns') #ustunlarni tashlab yuborish
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 16        31.4  1.66    73.91
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77

# %%
df.drop('Yil', axis = 'columns', inplace = True) # asl datafreymni ham o'zgartirish

# %%
df
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 16        31.4  1.66    73.91
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77
