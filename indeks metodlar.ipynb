# %%
import pandas as pd

# %%
import numpy as np

# %%
data = {
    'Uzbekistan' : {2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan' : {2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
usernames = {'anvar':'anvarbeks223', 'olim':'olimtoy', 'maryam':'maryam334455', 'javohir':'javohir445'}
emails = {'anvar':'anvar@gmail.com', 'olim':'olim@mail.ru', 'maryam':'mary33@gmail.com', 'javohir':'javohir445@gmail.com'}

data = {
    'username' : usernames,
    'email' : emails
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#              username                 email
# anvar    anvarbeks223       anvar@gmail.com
# olim          olimtoy          olim@mail.ru
# maryam   maryam334455      mary33@gmail.com
# javohir    javohir445  javohir445@gmail.com

# %%
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
data2 = {
    'username':{'olim':'olimjon21', 'maryam':'maryam2020'},
    'email':{'olim':'olimjon21@gmail.com', 'maryam':'maryam2020@mail.ru'}
}

# %%
df2 = pd.concat([df, pd.DataFrame(data2)]) # eski append metodi
df2
# Out:
#              username                 email
# anvar    anvarbeks223       anvar@gmail.com
# olim          olimtoy          olim@mail.ru
# maryam   maryam334455      mary33@gmail.com
# javohir    javohir445  javohir445@gmail.com
# olim        olimjon21   olimjon21@gmail.com
# maryam     maryam2020    maryam2020@mail.ru

# %%
newind = pd.Index(['olim', 'nafisa', 'hamida'])

# %%
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.isin(df2.index) #newind qiymatlari df2 indeksi ichida bor yo'qligini tekshiradi
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newind) #df2 hamda newind indekslari o'rtasidafi farqli qiymatlarni qaytaradi
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')

# %%
newind.difference(df2.index)
# Out:
# Index(['hamida', 'nafisa'], dtype='object')

# %%
df2.index.union(newind)
# Out:
# Index(['anvar', 'hamida', 'javohir', 'maryam', 'maryam', 'nafisa', 'olim',
#        'olim'],
#       dtype='object')

# %%
df2
# Out:
#              username                 email
# anvar    anvarbeks223       anvar@gmail.com
# olim          olimtoy          olim@mail.ru
# maryam   maryam334455      mary33@gmail.com
# javohir    javohir445  javohir445@gmail.com
# olim        olimjon21   olimjon21@gmail.com
# maryam     maryam2020    maryam2020@mail.ru

# %%
df2.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.drop('nafisa')
# Out:
# Index(['olim', 'hamida'], dtype='object')

# %%
df2.index.insert(2,'masha') #indeks raqamiga ko'ra yangi indeks qo'shish
# Out:
# Index(['anvar', 'olim', 'masha', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
df2
# Out:
#              username                 email
# anvar    anvarbeks223       anvar@gmail.com
# olim          olimtoy          olim@mail.ru
# maryam   maryam334455      mary33@gmail.com
# javohir    javohir445  javohir445@gmail.com
# olim        olimjon21   olimjon21@gmail.com
# maryam     maryam2020    maryam2020@mail.ru

# %%
df2.index.is_monotonic_increasing # alifbo tartibidami yoki yoq tekshiradi
# Out:
# False

# %%
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.is_unique # har xil qiymatlarmi yoki bir xil tekshiradi
# Out:
# True

# %%
df2.index.unique() #takrorlanmas qiymatlarni qaytaradi yoki faqat birinchi takrorlangan qiymatni
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')
